# %% [markdown]
# ### Pretrained GloVe Embeddings

# %%
import gensim.downloader as api

# %%
import numpy as np

# %%
models_info = api.info()["models"]

# %%
models_info.keys()
# Out:
# dict_keys(['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis'])

# %%
models_info["glove-twitter-50"]
# Out:
# {'num_records': 1193514,
#  'file_size': 209216938,
#  'base_dataset': 'Twitter (2B tweets, 27B tokens, 1.2M vocab, uncased)',
#  'reader_code': 'https://github.com/RaRe-Technologies/gensim-data/releases/download/glove-twitter-50/__init__.py',
#  'license': 'http://opendatacommons.org/licenses/pddl/',
#  'parameters': {'dimension': 50},
#  'description': 'Pre-trained vectors based on 2B tweets, 27B tokens, 1.2M vocab, uncased (https://nlp.stanford.edu/projects/glove/)',
#  'preprocessing': 'Converted to w2v format with `python -m gensim.scripts.glove2word2vec -i <fname> -o glove-twitter-50.txt`.',
#  'read_more': ['https://nlp.stanford.edu/projects/glove/',
#   'https://nlp.stanford.edu/pubs/glove.pdf'],
#  'checksum': 'c168f18641f8c8a00fe30984c4799b2b',
#  'file_name': 'glove-twitter-50.gz',
#  'parts': 1}

# %%
g_wv = api.load("glove-twitter-50") #50 dimension
# Out:
# [==================================================] 100.0% 199.5/199.5MB downloaded

# %%
g_wv

# %%
g_wv.index_to_key
# Out:
# ['<user>',
#  '.',
#  ':',
#  'rt',
#  ',',
#  '<repeat>',
#  '<hashtag>',
#  '<number>',
#  '<url>',
#  '!',
#  'i',
#  'a',
#  '"',
#  'the',
#  '?',
#  'you',
#  'to',
#  '(',
#  '<allcaps>',
#  '<elong>',
#  ')',
#  'me',
#  'de',
#  '<smile>',
#  '！',
#  'que',
#  'and',
#  '。',
#  '-',
#  'my',
#  'no',
#  '、',
#  'is',
#  'it',
#  '…',
#  'in',
#  'n',
#  'for',
#  '/',
#  'of',
#  'la',
#  "'s",
#  '*',
#  'do',
#  "n't",
#  'that',
#  'on',
#  'y',
#  "'",
#  'e',
#  'o',
#  'u',
#  'en',
#  'this',
#  'el',
#  'so',
#  'be',
#  "'m",
#  'with',
#  'just',
#  '>',
#  'your',
#  '^',
#  'like',
#  'have',
#  'te',
#  'at',
#  '？',
#  'love',
#  'se',
#  'are',
#  '<',
#  'm',
#  'r',
#  'if',
#  'all',
#  'b',
#  '・',
#  'not',
#  'but',
#  'we',
#  'es',
#  'ya',
#  '&',
#  'follow',
#  'up',
#  'what',
#  'get',
#  'lol',
#  'un',
#  '♥',
#  'lo',
#  'when',
#  'was',
#  '“',
#  '”',
#  'one',
#  'por',
#  'si',
#  'out',
#  '_',
#  'mi',
#  'can',
#  '<sadface>',
#  'من',
# ...

# %%
len(g_wv.index_to_key)
# Out:
# 1193514

# %%
g_wv.__getitem__("king")
# Out:
# array([-0.77201  , -0.16548  ,  0.22263  , -0.56608  ,  0.15602  ,
#        -0.050659 ,  0.076896 ,  0.90058  , -0.22829  , -0.083794 ,
#        -0.0087308,  0.12425  , -3.6283   , -0.70631  ,  0.3391   ,
#        -0.26866  ,  0.012886 ,  0.1314   ,  0.13072  ,  0.1594   ,
#        -0.43884  ,  0.30631  , -0.51841  , -0.86402  ,  0.89706  ,
#        -0.29222  ,  0.071633 , -0.7285   ,  0.47514  , -0.54581  ,
#         0.37375  , -0.2815   , -0.82164  , -0.1245   ,  0.06561  ,
#         0.2686   ,  0.12587  , -0.50189  ,  0.41322  , -0.40509  ,
#        -0.88866  , -0.71627  , -0.010728 , -0.29513  ,  0.098062 ,
#         0.47936  ,  0.49517  , -0.30246  ,  0.37465  ,  0.010619 ],
#       dtype=float32)

# %%
g_wv.__getitem__("queen")
# Out:
# array([-1.1483  ,  0.056701,  0.45495 ,  0.78913 ,  0.12648 , -0.26203 ,
#         1.0416  ,  0.81926 ,  0.16787 , -0.024409, -0.32818 , -0.26686 ,
#        -3.3949  , -0.51973 ,  0.099631, -0.19844 , -0.25297 ,  0.32921 ,
#        -0.10087 ,  0.62074 , -0.07907 , -0.26732 , -0.40307 , -0.28702 ,
#         1.1004  ,  0.12477 , -0.44017 ,  0.079431,  0.41238 , -0.43621 ,
#        -0.14126 , -0.51883 ,  0.060997, -0.43023 , -0.1929  , -0.036752,
#         0.51238 , -0.042892, -0.30856 ,  0.015481, -1.0621  , -0.7495  ,
#        -0.34737 ,  0.64046 , -0.29651 , -0.19719 ,  0.2932  , -0.13418 ,
#         0.1935  , -0.4291  ], dtype=float32)

# %%
g_wv.__getitem__("women")
# Out:
# array([-0.0095018, -0.39174  ,  0.24654  ,  0.33996  , -0.09155  ,
#         0.51096  ,  0.5034   ,  0.34401  , -0.52964  ,  0.18547  ,
#        -1.1866   ,  0.12359  , -4.5775   ,  1.0205   ,  0.36412  ,
#         0.26679  , -0.84761  , -0.78148  ,  1.3381   ,  0.27346  ,
#         0.11411  , -0.38546  ,  0.35626  , -0.62998  ,  0.37237  ,
#         1.2669   ,  0.21405  ,  0.88096  , -0.43402  , -0.37307  ,
#         0.69983  , -0.40784  ,  0.5658   ,  0.20292  ,  1.0911   ,
#        -0.80045  , -0.46643  ,  0.69651  ,  0.12991  , -1.1267   ,
#        -0.70159  , -0.13415  ,  0.1994   ,  0.56815  ,  0.12656  ,
#        -0.91078  ,  0.78983  ,  0.63947  , -0.33812  , -0.5523   ],
#       dtype=float32)

# %%
word1 = g_wv.__getitem__("hyderabad")

# %%
word2 = g_wv.__getitem__("mumbai")

# %%
from scipy.spatial import distance

# %%
g_wv.cosine_similarities(word1, [word2])
# Out:
# array([0.84004796], dtype=float32)

# %%
king = g_wv.__getitem__("king")
data = g_wv.__getitem__("data")

# %%
g_wv.cosine_similarities(king, [data])
# Out:
# array([0.2249634], dtype=float32)

# %%
man = g_wv.__getitem__("man")
women = g_wv.__getitem__("women")

# %%
g_wv.cosine_similarities(man, [women])
# Out:
# array([0.6130889], dtype=float32)

# %%
g_wv.most_similar("learn")
# Out:
# [('teach', 0.9219712018966675),
#  ('understand', 0.88901686668396),
#  ('easy', 0.8729665279388428),
#  ('learning', 0.8681188821792603),
#  ('able', 0.8638690114021301),
#  ('ways', 0.86271071434021),
#  ('learned', 0.8590569496154785),
#  ('how', 0.8581041693687439),
#  ('can', 0.8579123020172119),
#  ('trying', 0.8539852499961853)]

# %%
g_wv.most_similar("elon")
# Out:
# [('juniper', 0.7311159372329712),
#  ('copernicus', 0.7298702597618103),
#  ('vikram', 0.7235859036445618),
#  ('stratus', 0.7172914147377014),
#  ('trimble', 0.7135363221168518),
#  ('tesla', 0.711685836315155),
#  ('crytek', 0.7088427543640137),
#  ('spacex', 0.7073233723640442),
#  ('sanya', 0.700840950012207),
#  ('bioware', 0.7003998756408691)]

# %%
g_wv.similarity("king","queen")
# Out:
# np.float32(0.7713881)

# %%
g_wv.__getitem__(["king","queen"])
# Out:
# array([[-0.77201  , -0.16548  ,  0.22263  , -0.56608  ,  0.15602  ,
#         -0.050659 ,  0.076896 ,  0.90058  , -0.22829  , -0.083794 ,
#         -0.0087308,  0.12425  , -3.6283   , -0.70631  ,  0.3391   ,
#         -0.26866  ,  0.012886 ,  0.1314   ,  0.13072  ,  0.1594   ,
#         -0.43884  ,  0.30631  , -0.51841  , -0.86402  ,  0.89706  ,
#         -0.29222  ,  0.071633 , -0.7285   ,  0.47514  , -0.54581  ,
#          0.37375  , -0.2815   , -0.82164  , -0.1245   ,  0.06561  ,
#          0.2686   ,  0.12587  , -0.50189  ,  0.41322  , -0.40509  ,
#         -0.88866  , -0.71627  , -0.010728 , -0.29513  ,  0.098062 ,
#          0.47936  ,  0.49517  , -0.30246  ,  0.37465  ,  0.010619 ],
#        [-1.1483   ,  0.056701 ,  0.45495  ,  0.78913  ,  0.12648  ,
#         -0.26203  ,  1.0416   ,  0.81926  ,  0.16787  , -0.024409 ,
#         -0.32818  , -0.26686  , -3.3949   , -0.51973  ,  0.099631 ,
#         -0.19844  , -0.25297  ,  0.32921  , -0.10087  ,  0.62074  ,
# ...

# %%
words = ["king","queen","mango","apple","men","women","good","bad","bike","car","india","food","wow","hyderabad","mumbai"]

# %%
len(words)
# Out:
# 15

# %%
X = g_wv.__getitem__(words)

# %%
X.shape
# Out:
# (15, 50)

# %%
X
# Out:
# array([[-7.7201e-01, -1.6548e-01,  2.2263e-01, -5.6608e-01,  1.5602e-01,
#         -5.0659e-02,  7.6896e-02,  9.0058e-01, -2.2829e-01, -8.3794e-02,
#         -8.7308e-03,  1.2425e-01, -3.6283e+00, -7.0631e-01,  3.3910e-01,
#         -2.6866e-01,  1.2886e-02,  1.3140e-01,  1.3072e-01,  1.5940e-01,
#         -4.3884e-01,  3.0631e-01, -5.1841e-01, -8.6402e-01,  8.9706e-01,
#         -2.9222e-01,  7.1633e-02, -7.2850e-01,  4.7514e-01, -5.4581e-01,
#          3.7375e-01, -2.8150e-01, -8.2164e-01, -1.2450e-01,  6.5610e-02,
#          2.6860e-01,  1.2587e-01, -5.0189e-01,  4.1322e-01, -4.0509e-01,
#         -8.8866e-01, -7.1627e-01, -1.0728e-02, -2.9513e-01,  9.8062e-02,
#          4.7936e-01,  4.9517e-01, -3.0246e-01,  3.7465e-01,  1.0619e-02],
#        [-1.1483e+00,  5.6701e-02,  4.5495e-01,  7.8913e-01,  1.2648e-01,
#         -2.6203e-01,  1.0416e+00,  8.1926e-01,  1.6787e-01, -2.4409e-02,
#         -3.2818e-01, -2.6686e-01, -3.3949e+00, -5.1973e-01,  9.9631e-02,
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)

# %%
X_pca = pca.fit_transform(X)

# %%
X.shape
# Out:
# (15, 50)

# %%
X_pca.shape
# Out:
# (15, 2)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.24783085, 0.15479381], dtype=float32)

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# np.float32(0.40262467)

# %%
X_pca
# Out:
# array([[-0.56938577,  0.6999408 ],
#        [-0.6444054 ,  0.15569335],
#        [-0.36410412,  3.172245  ],
#        [-0.8352544 ,  2.6655707 ],
#        [-0.5394659 , -2.4094296 ],
#        [-0.1668318 , -2.3721359 ],
#        [-2.3049495 , -0.5766419 ],
#        [-2.0021017 , -0.8157578 ],
#        [ 0.19498362, -1.0822539 ],
#        [-0.8495349 , -0.5980185 ],
#        [ 2.3005595 , -0.04529697],
#        [-1.018826  ,  1.3753306 ],
#        [-1.3868655 , -0.21344459],
#        [ 4.291729  , -0.09392807],
#        [ 3.8944497 ,  0.138126  ]], dtype=float32)

# %%
np.sum(pca.explained_variance_ratio_)
# Out:
# np.float32(0.40262467)

# %%
X_pca[:,0]
# Out:
# array([-0.56938577, -0.6444054 , -0.36410412, -0.8352544 , -0.5394659 ,
#        -0.1668318 , -2.3049495 , -2.0021017 ,  0.19498362, -0.8495349 ,
#         2.3005595 , -1.018826  , -1.3868655 ,  4.291729  ,  3.8944497 ],
#       dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.scatter(X_pca[:,0], X_pca[:,1])

for i,word in enumerate(words):
    plt.annotate(word, xy = (X_pca[i,0], X_pca[i,1]))
plt.show()
