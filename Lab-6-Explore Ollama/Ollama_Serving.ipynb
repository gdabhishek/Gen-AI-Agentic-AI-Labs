# %%
#install ollama

# Downloads and executes the ollama installation script
# !curl -fsSL https://ollama.com/install.sh | sh

# %%
#download the tgz/zip ngrok -- file

# Downloads the ngrok archive
# !wget https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz

# %%
#unzip the tgz
# Extracts the ngrok executable from the downloaded archive
# !tar xvzf ngrok-v3-stable-linux-amd64.tgz ngrok

# %%
# Lists the files in the current directory
# !ls

# %%
# Authenticates ngrok with your authtoken
# !./ngrok authtoken <ngrok_authtoken>

# %%
#Download the model
# This is a commented out command that would have run the llama3:8b model
#!ollama run llama3:8b

# %%
#serve the ollama in ngrok with port 11434

#after 5 sconds

#ollama run llama3:8b -- download the model(llama3:8b) and serve it
# Starts the ollama server, tunnels it through ngrok, waits 5 seconds, and then runs the gemma3:12b model
# !ollama serve & ./ngrok http 11434 --host-header="localhost:11434" --log stdout & sleep 5s && ollama run gemma3:12b
